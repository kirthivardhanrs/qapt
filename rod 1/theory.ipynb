# %%
vars(globals()["__buil" + chr(116) + "ins__"])["prin" + chr(116)](_)
# Out:
# <function print>

# %%
ord("A")
# Out:
# 65

# %%
conn = remote("nc amt.rs", 31671)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 conn = remote("nc amt.rs", 31671)
#
# NameError: name 'remote' is not defined

# %%
[i for i in __builtins__.__dict__.keys() if "t" not in i and "i" not in i and "l" not in i and "e" not in i ]
# Out:
# ['__doc__',
#  'abs',
#  'any',
#  'chr',
#  'hash',
#  'max',
#  'ord',
#  'pow',
#  'round',
#  'sum',
#  'vars',
#  'map',
#  'OSError',
#  'IOError',
#  'EOFError',
#  'TabError',
#  'LookupError',
#  '__IPYTHON__']

# %%
_="b"
try:
    code = ascii(input("Give code: "))
    if "flag" in code or "e" in code or "t" in code or "\\" in code:
        raise ValueError("invalid input")
    exec(eval(code))
except Exception as err:
    print(err)

# %%
class Balls:
    1+1
_="balls"
vars(__builtins__)
# Out:
# {'__name__': 'builtins',
#  '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  '__build_class__': <function __build_class__>,
#  '__import__': <function __import__>,
#  'abs': <function abs(x, /)>,
#  'all': <function all(iterable, /)>,
#  'any': <function any(iterable, /)>,
#  'ascii': <function ascii(obj, /)>,
#  'bin': <function bin(number, /)>,
#  'breakpoint': <function breakpoint>,
#  'callable': <function callable(obj, /)>,
#  'chr': <function chr(i, /)>,
#  'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#  'delattr': <function delattr(obj, name, /)>,
#  'dir': <function dir>,
#  'divmod': <function divmod(x, y, /)>,
# ...

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'globals()["__buil" + chr(116) + "ins__"]',
#   'locals()',
#   'globals()',
#   'globals()["__buil" + chr(116) + "ins__"]["print"]',
#   'globals()["__buil" + chr(116) + "ins__"].__dict__()',
#   'globals()["__buil" + chr(116) + "ins__"].__dict__',
#   'globals()[chr(95) + chr(95) + chr(98) + chr(117) + chr(105) + chr(108) + chr(105) + chr(110) + chr(115)][chr(95) + chr(95) + chr(103) + chr(101) + chr(116) + chr(105) + chr(116) + chr(101) + chr(109)]()',
#   'globals()["__builtins__"][chr(95) + chr(95) + chr(103) + chr(101) + chr(116) + chr(105) + chr(116) + chr(101) + chr(109)]()',
#   'globals()["__buil" + chr(116) + "ins__"].__class__.__base__.__subclasses__()',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'globals()["__buil" + chr(116) + "ins__"]',
#   'locals()',
#   'globals()',
#   'globals()["__buil" + chr(116) + "ins__"]["print"]',
#   'globals()["__buil" + chr(116) + "ins__"].__dict__()',
#   'globals()["__buil" + chr(116) + "ins__"].__dict__',
#   'globals()[chr(95) + chr(95) + chr(98) + chr(117) + chr(105) + chr(108) + chr(105) + chr(110) + chr(115)][chr(95) + chr(95) + chr(103) + chr(101) + chr(116) + chr(105) + chr(116) + chr(101) + chr(109)]()',
#   'globals()["__builtins__"][chr(95) + chr(95) + chr(103) + chr(101) + chr(116) + chr(105) + chr(116) + chr(101) + chr(109)]()',
#   'globals()["__buil" + chr(116) + "ins__"].__class__.__base__.__subclasses__()',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'globals()["__buil" + chr(116) + "ins__"]', 'locals()'],
#  '_oh': {1: <module 'builtins' (built-in)>},
#  '_dh': [WindowsPath('c:/Users/user/Downloads'),
#   WindowsPath('c:/Users/user/Downloads')],
#  'In': ['', 'globals()["__buil" + chr(116) + "ins__"]', 'locals()'],
#  'Out': {1: <module 'builtins' (built-in)>},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001D34C7FEAA0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1d34c7ff100>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1d34c7ff100>,
# ...

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'globals()["__buil" + chr(116) + "ins__"]',
#   'locals()',
#   'globals()'],
#  '_oh': {1: <module 'builtins' (built-in)>, 2: {...}},
#  '_dh': [WindowsPath('c:/Users/user/Downloads'),
#   WindowsPath('c:/Users/user/Downloads')],
#  'In': ['',
#   'globals()["__buil" + chr(116) + "ins__"]',
#   'locals()',
#   'globals()'],
#  'Out': {1: <module 'builtins' (built-in)>, 2: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001D34C7FEAA0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1d34c7ff100>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1d34c7ff100>,
# ...

# %%
__builtins__
# Out:
# <module 'builtins' (built-in)>

# %%
vars(globals()["__buil" + chr(116) + "ins__"])
# Out:
# {'__name__': 'builtins',
#  '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  '__build_class__': <function __build_class__>,
#  '__import__': <function __import__>,
#  'abs': <function abs(x, /)>,
#  'all': <function all(iterable, /)>,
#  'any': <function any(iterable, /)>,
#  'ascii': <function ascii(obj, /)>,
#  'bin': <function bin(number, /)>,
#  'breakpoint': <function breakpoint>,
#  'callable': <function callable(obj, /)>,
#  'chr': <function chr(i, /)>,
#  'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#  'delattr': <function delattr(obj, name, /)>,
#  'dir': <function dir>,
#  'divmod': <function divmod(x, y, /)>,
# ...

# %%
ord("t")
# Out:
# 116

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '__builtins__',
#   'globals()',
#   'globals()["__builtins__"]',
#   'ord("t")',
#   'vars()'],
#  '_oh': {1: <module 'builtins' (built-in)>,
#   2: {...},
#   3: <module 'builtins' (built-in)>,
#   4: 116},
#  '_dh': [WindowsPath('c:/Users/user/Downloads')],
#  'In': ['',
#   '__builtins__',
#   'globals()',
#   'globals()["__builtins__"]',
#   'ord("t")',
#   'vars()'],
#  'Out': {1: <module 'builtins' (built-in)>,
#   2: {...},
#   3: <module 'builtins' (built-in)>,
#   4: 116},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000027A52FB8940>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x27a52f32220>,
# ...

# %%
{}[_]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\Downloads\2.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Downloads/2.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> {}[_]
#
# KeyError: 'a'

# %%
_="a"

# %%
"1e25v768h1e66dw61v1hv1kl6aa1ei1pw1pv1ju1kj5ps1bb6lw624".translate(str.maketrans("1e25v74", "BDSEC{}"))
# Out:
# 'BDSEC{68hBD66dw6BCBhCBkl6aaBDiBpwBpCBjuBkjEpsBbb6lw6S}'

# %%
chr(147+66-19)
# Out:
# 'Â'

# %%
ord("B")
# Out:
# 66

# %%
from PIL import Image

# %%
import os

# %%
data=b""
for i in os.listdir("What is this "):
    data+= open("What is this /" + i, "rb").read()

# %%
open("suwarro.png", "wb").write(data)
# Out:
# 362204

# %%
import numpy as np
from scipy.integrate import odeint
import csv
import pandas as pd

# %%
g = 9.81
l = 1
A = 0.04
w = 140

theta_o = 0.1

def dthdt(th, t):
    th, thp = th
    dthdt = thp
    dthpdt = (2 * np.cos(th) + w * A * np.sin(w * t) * thp + 2 * g * l * np.sin(th)) / (2 * l)
    return [dthdt, dthpdt]

t = np.linspace(0, 10, 50)
sol = odeint(dthdt, [theta_o, 0], t)

th = sol[:, 0]

plt.scatter(t, th)

# %%
g = 9.81
l = 1
A = 0.04
w = 140

theta_o = 0.1

def dthdt(th, t):
    th, thp = th
    dthdt = thp
    #dthpdt = (2 * l * np.cos(th) + w * A * np.sin(w * t) * thp + 2 * g * l * np.sin(th) - 2*l*A*w*(np.cos(th)*np.cos(w*t) - thp*np.sin(w*t)*np.sin(th))) / (2 * l**2)
    dthpdt = (2*thp*l*A*w*np.sin(w*t)*np.cos(th) + 2*g*l*np.sin(th) - 2*A*w*l*(thp*np.cos(th)*np.sin(w*t) + w*np.sin(th)*np.cos(w*t)))/(2*l**2)
    return [dthdt, dthpdt]

t = np.linspace(0, 10, 1000)
sol = odeint(dthdt, [theta_o, 0], t)

th = sol[:, 0]

# %%
data = pd.read_csv("inverted-pendulum/rod 1/set9/data1.csv", header=None)
l1 = plt.scatter(t, th, alpha=0.8)
l2 = plt.scatter(data[0], data[1], color="red", alpha=0.8)
plt.title("Set 9")
plt.xlabel("t/s")
plt.xlabel("θ/rad")
plt.gca().legend(["Theory","Data"])
plt.plot()
plt.savefig("set9.png", transparent=True)

# %%
from tqdm.notebook import tqdm

# %%
g = 9.81
l = 1
A = 0.04
#w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for w in tqdm(range(1, 200)):
    maxth.append([w,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])
# Out:
#   0%|          | 0/199 [00:00<?, ?it/s]

# %%
plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("omega")
plt.ylabel("theta_Max")
# Out:
# Text(0, 0.5, 'theta_Max')

# %%
g = 9.81
l = 1
A = 0.04
#w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for w in tqdm(np.linspace(110, 112, 50)):
    maxth.append([w,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("omega")
plt.ylabel("theta_Max")
plt.title("A=0.04")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'A=0.04')

# %%
g = 9.81
l = 1
A = 0.01
#w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for w in tqdm(np.linspace(30, 1000, 100)):
    maxth.append([w,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("omega")
plt.ylabel("theta_Max")
plt.title("A=0.01")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'A=0.01')

# %%
g = 9.81
l = 1
A = 0.01
w = 111
t = np.linspace(0, 10, 50)
maxth=[]
for A in tqdm(np.linspace(0.01, 0.1, 100)):
    maxth.append([A,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("A")
plt.ylabel("theta_Max")
plt.title("w=111")
plt.plot()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
g = 9.81
l = 1
A = 0.01
w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for A in tqdm(np.linspace(0.01, 0.1, 100)):
    maxth.append([A,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("A")
plt.ylabel("theta_Max")
plt.title("w=100")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'w=100')

# %%
g = 9.81
l = 1
A = 0.01
w = 111
t = np.linspace(0, 10, 50)
maxth=[]
for A in tqdm(np.linspace(0.038, 0.042, 100)):
    maxth.append([A,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("A")
plt.ylabel("theta_Max")
plt.title("w=111")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'w=111')

# %%
g = 9.81
l = 1
A = 0.01
w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for A in tqdm(np.linspace(0.042, 0.048, 100)):
    maxth.append([A,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("A")
plt.ylabel("theta_Max")
plt.title("w=100")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'w=100')

# %%
g = 9.81
l = 1
Aw = 4.43
#w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for w in tqdm(range(50,200)):
    A = Aw/w
    maxth.append([w,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("w")
plt.ylabel("theta_Max")
plt.title("Aw=4.43")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'Aw=4.43')

# %%
g = 9.81
l = 1
Aw = 4.44
#w = 100
t = np.linspace(0, 10, 50)
maxth=[]
for w in tqdm(range(50,200)):
    A = Aw/w
    maxth.append([w,abs(max(odeint(dthdt, [0.1, 0], t)[:, 0], key = lambda th:abs(th)))])

plt.scatter([i[0] for i in maxth], [i[1] for i in maxth])
plt.xlabel("w")
plt.ylabel("theta_Max")
plt.title("Aw=4.43")
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Text(0.5, 1.0, 'Aw=4.43')
